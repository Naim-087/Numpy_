# %% [markdown]
# # Random_Number

# %% [markdown]
# ## Random_int

# %%
import numpy as np
from numpy import random
x = random.randint(100)
x
# Out:
# 41

# %%
np.random.randint(100,160,size=(50))
# Out:
# array([113, 150, 100, 115, 151, 142, 113, 105, 147, 142, 144, 109, 123,
#        153, 158, 145, 101, 127, 105, 106, 128, 104, 141, 157, 108, 150,
#        103, 122, 117, 104, 147, 154, 130, 138, 141, 135, 135, 138, 151,
#        141, 158, 135, 114, 112, 133, 142, 157, 142, 128, 156])

# %% [markdown]
# ## Random_float

# %%
x = np.random.rand(23,40)
print(x)
x.shape
# Out:
# [[3.19874068e-01 1.47514803e-01 7.23712393e-01 7.68268250e-02
#   3.11280721e-01 4.43051542e-01 1.70227114e-03 5.45426002e-01
#   7.06632605e-02 4.98199783e-01 7.81673597e-01 1.48045284e-01
#   3.42244610e-01 6.30600517e-02 3.09133000e-01 1.69989628e-01
#   4.28519394e-01 3.19505098e-01 7.41078851e-01 3.53707317e-01
#   9.44187598e-01 9.89845837e-01 6.67395962e-01 5.00855557e-01
#   6.55747389e-01 5.77437245e-01 5.77980736e-01 6.69627074e-01
#   4.45848407e-01 8.83277266e-01 6.91109571e-01 1.96197854e-01
#   5.04431452e-01 7.05353618e-01 3.75898893e-01 8.00813703e-01
#   7.27943358e-01 2.99719188e-01 1.51531277e-01 9.45445681e-01]
#  [7.14410420e-03 5.90898784e-01 9.11353430e-01 2.77356805e-01
#   9.05025185e-01 2.61414412e-01 8.26473766e-01 3.49933867e-01
#   6.90285899e-01 4.97903395e-01 8.00927852e-01 6.64772317e-01
#   4.66857518e-01 9.22786538e-01 3.54285797e-01 7.65953064e-01
#   3.51274819e-02 2.08725497e-01 5.06494643e-01 8.48338980e-01
# ...

# %% [markdown]
# ## Integer_2D_array

# %%
x= np.random.randint(2,20,size=(3,4))
x
# Out:
# array([[19,  2, 10,  7],
#        [17,  4,  3, 19],
#        [ 3,  8, 11,  4]])

# %% [markdown]
# ## Int_3D_array

# %%
y=random.randint(9,13,size=(3,4,4))
y
# Out:
# array([[[ 9, 12, 11, 10],
#         [11, 12,  9, 12],
#         [11, 12, 12, 12],
#         [10, 10, 12, 11]],
#
#        [[ 9, 12, 10, 11],
#         [10, 10,  9,  9],
#         [10, 12, 12, 12],
#         [ 9, 11, 10, 12]],
#
#        [[11, 11, 10,  9],
#         [10, 10, 11,  9],
#         [11, 12, 12,  9],
#         [11, 11, 10, 11]]])

# %% [markdown]
# ## Float_2D_Array_Generate

# %%
x= random.rand(3,5)
x
# Out:
# array([[0.80638987, 0.0530546 , 0.32039847, 0.43658349, 0.00291784],
#        [0.49094953, 0.62297166, 0.84868315, 0.10343555, 0.82085219],
#        [0.08566129, 0.30245932, 0.65328176, 0.09253944, 0.42664955]])

# %% [markdown]
# ## Flaot_3D_Array

# %%
x= np.random.rand(4,3,4)
x
# Out:
# array([[[0.55235192, 0.93945755, 0.0880389 , 0.64959463],
#         [0.6149255 , 0.74125592, 0.65911224, 0.9436283 ],
#         [0.1835248 , 0.96204298, 0.27859054, 0.46187012]],
#
#        [[0.3002557 , 0.1865202 , 0.4309791 , 0.48282303],
#         [0.90058332, 0.43898273, 0.04346564, 0.38634648],
#         [0.79940589, 0.58711985, 0.62815227, 0.78978928]],
#
#        [[0.40703523, 0.28475332, 0.15945131, 0.27375406],
#         [0.0443131 , 0.04622604, 0.37933239, 0.32513712],
#         [0.05590308, 0.34184243, 0.62637381, 0.6753882 ]],
#
#        [[0.24858722, 0.04302284, 0.95708637, 0.18939737],
#         [0.22884171, 0.86498791, 0.24027485, 0.31953862],
#         [0.16812285, 0.61488163, 0.82643472, 0.22072906]]])

# %% [markdown]
# ## Flaot_CustomRange_3D_Array

# %%
y=np.random.uniform(5,9,size=(4,3,5))
y
# Out:
# array([[[7.38302171, 8.61742647, 6.59757444, 6.52690187, 6.25247714],
#         [6.47457535, 6.41878725, 7.65912452, 8.42070897, 6.92660955],
#         [7.74605732, 5.18006307, 5.18411084, 6.97082526, 6.80725125]],
#
#        [[5.46834951, 7.74101906, 7.88300971, 8.09812376, 6.54361984],
#         [6.52747292, 5.99456844, 7.42223485, 5.04893502, 6.36340774],
#         [5.46979853, 5.74787306, 8.02812142, 6.33148726, 7.50483493]],
#
#        [[5.72203955, 6.54553323, 5.48743485, 8.60471024, 6.78127149],
#         [5.20651518, 5.42185473, 6.65340829, 6.000648  , 5.27960469],
#         [7.59827212, 7.67101696, 5.73986017, 8.114706  , 8.57854856]],
#
#        [[7.1945588 , 8.5565416 , 5.42412422, 6.24408836, 7.54782913],
#         [8.50876749, 8.60777546, 5.339106  , 6.89254274, 5.37093086],
#         [7.72848581, 7.6539552 , 5.13145408, 5.54181566, 6.45518525]]])

# %% [markdown]
# # Distribuition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Uniform_Distribution

# %% [markdown]
# Used to describe probability where every event has equal chances of occuring.
#
#  Generation of random numbers.
#
# It has three parameters:
#
# low - lower bound - default 0.0
#
# high - upper bound - default 1.0
#
# size - The shape of the returned array

# %%
x=random.uniform(size=(3,4))
x
# Out:
# array([[0.95633125, 0.29594271, 0.50564442, 0.86742578],
#        [0.36551423, 0.08756951, 0.8458328 , 0.19903073],
#        [0.53289607, 0.78279737, 0.88444689, 0.1090102 ]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(random.uniform(size=(1000)),kde=True)

plt.show()

# %% [markdown]
# ## Normal_Distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.random.normal(loc=0,scale=1,size=(1000))
# Out:
# array([ 1.89560429e-01,  2.72028264e-01,  7.04022749e-01, -4.85195178e-01,
#        -1.53018154e+00,  3.22998047e-01, -7.25934177e-01,  4.96700737e-01,
#        -1.33407081e+00,  7.07406946e-01,  1.62144736e+00, -9.30764795e-01,
#         3.30513550e-01,  1.58528040e-01,  1.29793274e-01,  9.92458342e-01,
#        -4.56627142e-01,  9.74101183e-01,  4.48447436e-02,  1.61516619e+00,
#         3.23879499e-01, -2.21686916e+00, -1.33930562e+00, -8.77832084e-01,
#         9.76201469e-01,  5.22853039e-01,  9.86301533e-01, -1.45770285e+00,
#         6.85842812e-01,  5.51660499e-01,  2.42101439e-01, -1.96711545e+00,
#         6.41878922e-01, -8.73323175e-01,  4.76271327e-01,  1.48116483e+00,
#         1.12685451e+00, -7.19852653e-01,  4.12890084e-02,  5.85674844e-01,
#         1.20775267e+00,  5.01482444e-01,  7.06289221e-03,  5.31683483e-01,
#         1.56502538e+00, -8.27693509e-01, -1.61828492e+00,  3.93723178e-01,
# ...

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.normal(loc=0,scale=1,size=1000), kind="kde")

plt.show()

# %%
sns.displot(random.normal(loc=-2,scale=1,size=1000), kind="kde")

plt.show()

# %% [markdown]
# ## Bionimial_Distribution

# %% [markdown]
# Binomial Distribution is a Discrete Distribution.
#
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
#
# It has three parameters:
#
# n - number of trials.
#
# p - probability of occurrence of each trial (e.g. for toss of a coin 0.5 each).
#
# size - The shape of the returned array.

# %%
a = random.binomial(n=10,p=0.75,size=1000)
a
# Out:
# array([ 9,  8,  7,  6,  9,  8,  7,  7,  9,  6,  7,  9,  8,  7,  8,  8,  7,
#         8,  8,  7,  6,  8,  7,  9,  6,  9,  4,  5,  7,  9,  7,  9,  7,  9,
#         9,  6,  7,  6,  6,  8,  8,  5,  9,  8,  6,  5,  9,  6,  7,  8,  6,
#         8,  7,  9,  9,  7,  6,  7,  8,  9,  6,  7,  7,  8,  8,  8,  7,  6,
#         8,  8,  6,  7,  7,  5,  6,  8,  9,  7,  7,  7,  5,  5,  9,  8,  9,
#         7,  8,  8,  8,  9,  8,  8,  9,  7,  6,  8,  9,  8,  6,  8,  6,  7,
#         8,  7,  7,  6,  7,  7,  7,  6,  8,  8, 10,  8,  9,  7,  7,  9,  6,
#         8,  6,  9,  8, 10,  8,  5,  7,  6,  8,  8,  8,  7,  8,  7,  9,  7,
#        10,  7,  8, 10,  5,  6,  7,  6,  8,  6,  5,  8,  8,  8,  8,  9,  5,
#         8,  8,  7, 10, 10,  6,  8,  8,  8,  7,  7,  9,  8,  8,  9,  6,  8,
#         9,  6,  7,  5,  7,  8,  9,  9,  7,  6, 10,  9,  6,  5,  8, 10,  8,
#         9,  7,  6,  4,  7,  8,  6,  5,  7,  7,  7,  8,  8,  7,  9,  8,  7,
# ...

# %%
sns.displot(random.binomial(n=10, p=0.5, size=1000))

plt.show()

# %% [markdown]
# ## Poisson_Distribution

# %%
https://www.w3schools.com/python/numpy/numpy_random_poisson.asp

# %% [markdown]
# ## Multimonial_Distribution

# %% [markdown]
# https://www.w3schools.com/python/numpy/numpy_random_multinomial.asp

# %% [markdown]
# ## Chi_Square_Distribution

# %% [markdown]
# https://www.w3schools.com/python/numpy/numpy_random_chisquare.asp

# %% [markdown]
# ## Exponantial_Distribution

# %% [markdown]
# https://www.w3schools.com/python/numpy/numpy_random_exponential.asp
